# %%
Class parent:
    def func1(self):
        print("This function belongs to parent class")
 Class Child(parent):
     def func1(self):
         print("This function belongs to child class")
  object=Child()
  object.func1()
# Out:
#   File <string>:4
#     Class Child(parent):
#                         ^
# IndentationError: unindent does not match any outer indentation level

# %%
class Parent:
    def func1(self):
        print("This functon belongs to parent class")
class Child(parent):
   def func1(self):
       print("This function belongs to child Class")
object=Child()
object.func1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2     def func1(self):
#       3         print("This functon belongs to parent class")
# ----> 4 class Child(parent):
#       5    def func1(self):
#       6        print("This function belongs to child Class")
#
# NameError: name 'parent' is not defined

# %%
class parent:
    def func1(self):
        print("This function belongs to parent class")
class child(parent):
            def func1(self):
                print("This function belongs to child class")
obj= child()
obj. func1()
# Out:
# This function belongs to child class
