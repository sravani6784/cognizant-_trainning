# %%
name=["sravani","Raj","Rahul"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# sravani
# Raj
# Rahul

# %%
marks=[22,34,45,56,66,52]
it=iter(marks)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 22
# 34
# 45
# 56
# 66

# %%
def numbers():
  yield 1
  yield 2
  yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file = open("demo.txt","w")
file.write("Hello student")
file.close()

# %%
file=open("demo.txt" , "r" )
conent=file.read()
print(conent)
file.close()
# Out:
# Hello student

# %%
list=[1,2,3,4]
print(list[3])
# Out:
# 4

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %% [raw]
# try:
#      file=open("do,txt","r")
#      content=file.read()
#      print(content)
#      file.close()
# except :
#      print("file not found")

# %%
try:
    file=open("demo,text","r")
    content=file.read()
    priny(content)
    file.close()
except :
    print("file not found")
# Out:
# file not found

# %%
try:
    a=int(input("Enter the age:"))
except valueError:
    print("it is not a integer")

# %%
print("Hello world")
# Out:
# Hello world

# %%
a= 10
b= 20
a = a+b
b = a-b
a=  a-b
print("a =",a)
print("b =",b)
# Out:
# a = 20
# b = 10

# %%
p= float(input("Enter principal Ammount:"))
r= float(input("Enter Rate of Interst :"))
t =float(input("Enter Time :"))
si = (p* r * t)/100
print("simple Interest =",si)
# Out:
# Enter principal Ammount: 10000
# Enter Rate of Interst :  5
# Enter Time :  2
# simple Interest = 1000.0

# %%
num = int(input("Enter a number : "))
if num % 2 == 0:
    print("Even")
else:
    print("odd")
# Out:
# Enter a number :  5
# odd

# %%
 a = int(input("Enter frist number :"))
 b = int(input("Enter second number: "))
 c = int(input("Enter thrid number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else: 
    largest = c
 print("Largest number =",largest)
# Out:
# Enter frist number : 2
# Enter second number:  8
# Enter thrid number:  6
# Largest number = 8

# %%
marks = int(input("Enter marks: "))
if marks >= 90:
    grade = "A"
elif marks >= 75:
    grade = "B"
elif marks >= 60:
    grade =  "C"
elif marks >= 40:
    grade = "D"
else:
    grade = "F"
print("Grade =",grade)
# Out:
# Enter marks:  75
# Grade = B

# %%
num = input(input("Enter a number:"))
if num % 5==0 and num % 11 == 0:
    print("The number is didvvisible by both 5 and 11")
else:
    print("The number is not didvisble by both 5 and 11")

# %%
num = int(input("Enter a number: "))
count = len(str(abs(num)))
print("Number of digits =",count)

# %%
try:
    name=input("Enter the number")
    print(10/num)
except ValueError:
    print("Invalid Input")
except ZeroDivisionError:
   print("cannot divided by Zero")
else:
   print("program execute successfully")
finally:
    print("This block is going to execute everytime")
# Out:
# Enter the number r
# This block is going to execute everytime
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 try:
#       2     name=input("Enter the number")
# ----> 3     print(10/num)
#       4 except ValueError:
#       5     print("Invalid Input")
#
# NameError: name 'num' is not defined

# %%
age=int(input("Enter the age"))
if age<18:
   FalseException("you are not eligible for vote")
print("Eligible")
# Out:
# Enter the age 18
# Eligible

# %%
try:
    a=int(input("enter the number:"))
    b=int(input("enter the number:"))
    print(a/b)
except ZeroDivisionError:
    print("invalid")
except ValueError:
    print("invalid")
else:
    print("program execute successfully")
finally:
    print("thank you")
# Out:
# enter the number: 12
# enter the number: 12
# 1.0
# program execute successfully
# thank you

# %%
import numpy as np
arr=np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
import numpy as np
arr=np.array([20,30,490,50])
print(arr)
# Out:
# [20 30 40 50]

# %%
arr=np.array([[10,20],[20,30],[40,88]])
print(arr)
# Out:
# [[10 20]
#  [20 30]
#  [40 88]]
