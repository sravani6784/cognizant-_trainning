# %%
student_name=pd.Series(["sravs","akshaya","thashrin"])
print(student_name)
# Out:
# 0       sravs
# 1     akshaya
# 2    thashrin
# dtype: object

# %%
marks=pd.Series([10,20,30,43,50])
print(marks)
mark=pd.Series()
print(mark)
print(marks[1])
# Out:
# 0    10
# 1    20
# 2    30
# 3    43
# 4    50
# dtype: int64
# Series([], dtype: object)
# 20

# %%
Employee_salary=pd.Series([100000,200000,300000,400000,500000])
print(Employee_salary)
# Out:
# 0    100000
# 1    200000
# 2    300000
# 3    400000
# 4    500000
# dtype: int64

# %%
T=(10,20,30,40,50,60,80,100)
a=pd.Series(T)

print(a)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     80
# 7    100
# dtype: int64

# %%
student={"sravs":80,
          "sravani":50
        }
s=pd.Series(student)
print(s)
# Out:
# sravs      80
# sravani    50
# dtype: int64

# %%
ci=pd.Series([100,200,300],
      index=["a","b","c"]) 
print(ci)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
ci=pd.Series([100,200,300],
      index=["a","b","c"]) 
print(ci["b"])
# Out:
# 200

# %%
import pandas as pd
S=pd.Series([10,20,30,40])
print(S.sum())
print(S.max())
print(S.min())
print(S.mean())
print(S[S>=30])
# Out:
# 100
# 40
# 10
# 25.0
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
import  numpy as np
s=pd.Series([10,20,30,np.nan,40])
print(s)
print(s.isnull())
print(s.isnull().sum())
print(s.fillna(0))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    40.0
# dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 1
# 0    10.0
# 1    20.0
# 2    30.0
# 3     0.0
# 4    40.0
# dtype: float64

# %%
import pandas as pd
import  numpy as np
s=pd.Series([10,20,30,np.nan,40])
print(s)
print(s.isnull())
print(s.isnull().sum())
print(s.fillna(0))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    40.0
# dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 1
# 0    10.0
# 1    20.0
# 2    30.0
# 3     0.0
# 4    40.0
# dtype: float64

# %%
import pandas as pd
names=pd.Series(["sravs","amulya","abhi","nikky","nikky"])
print(names)
print(names.str.upper())
# Out:
# 0     sravs
# 1    amulya
# 2      abhi
# 3     nikky
# 4     nikky
# dtype: object
# 0     SRAVS
# 1    AMULYA
# 2      ABHI
# 3     NIKKY
# 4     NIKKY
# dtype: object

# %%
s=pd.Series([10,20,86,98,3,4,5])
print(S.sort_values())
print(S.sort_values(ascending=False))
print(S.unique())
print(S.value_counts())
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 4    40.0
# 3     NaN
# dtype: float64
# 4    40.0
# 2    30.0
# 1    20.0
# 0    10.0
# 3     NaN
# dtype: float64
# [10. 20. 30. nan 40.]
# 10.0    1
# 20.0    1
# 30.0    1
# 40.0    1
# Name: count, dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s.tolist())
# Out:
# [10, 20, 30, 40]

# %%
b=pd.Series([10,20,30,55])
print(b[b>40]& b[b<53])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
# C:\Users\Gopala Nandini\AppData\Local\Temp\ipykernel_23424\3055246699.py:2: FutureWarning: Operation between non boolean Series with different indexes will no longer return a boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   print(b[b>40]& b[b<53])
