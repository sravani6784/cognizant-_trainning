# %%
def square(x):
    return x*x

    
print(square(6))
# Out:
# 36

# %%
square= lambda x:x*x
print(square(3))
# Out:
# 9

# %%
mul= lambda a,b:a*b
print(mul(5,2))
# Out:
# 10

# %%
mul= lambda a,b:a*b
print(mul(15,40))
# Out:
# 600

# %%
check=lambda num:"Even" if  num%2==0 else "odd"
print(check(10))
# Out:
# Even

# %%
students=[("amulya",80),("teddy",75),("ramya",35)]
result=sorted(students, key=lambda x:x[1])
print(result)
# Out:
# [('ramya', 35), ('teddy', 75), ('amulya', 80)]

# %%
numbers = [1,2,3,4,5]
result = list(map(lambda x: x*x, numbers)) 
print(result)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [1,2,3,4,5]
result=list(filter(lambda num:num%2==0,numbers))
print(result)
# Out:
# [2, 4]

# %%
from functools import reduce
numbers=[1,2,3,4,5]
result=reduce(lambda x,y:x+y,numbers)
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
from functools import reduce
numbers=[1,2,3,4,5]
result=reduce(lambda x,y:x+y,numbers)
print(result)
# Out:
# 15
